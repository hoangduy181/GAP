# %%
# %pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.3.252-py3-none-any.whl.metadata (37 kB)
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# ...
#   Using cached torch-2.9.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (30 kB)
# ...
#   Using cached torchvision-0.24.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# ...
#   Using cached polars-1.37.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached polars_runtime_32-1.37.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached filelock-3.20.3-py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached fsspec-2026.1.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# ...

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolo11n-pose.yaml")  # build a new model from YAML
model = YOLO("yolo11l-pose.pt")  # load a pretrained model (recommended for training)
# model = YOLO("yolo11n-pose.yaml").load("yolo11n-pose.pt")  # build from YAML and transfer weights

# Train the model
# results = model.train(data="coco8-pose.yaml", epochs=100, imgsz=640)
# result = model.predict(source="../data/multiview_action_videos/a01/v01_s01_e00.avi", save=True, conf=0.5)
result = model.predict(source="/home/duyth/ai_coding/GAP/data/nturgb+d_rgb/S001C001P001R001A001_rgb.avi", save=True, conf=0.5)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/103) /home/duyth/ai_coding/GAP/data/nturgb+d_rgb/S001C001P001R001A001_rgb.avi: 384x640 1 person, 470.1ms
# video 1/1 (frame 2/103) /home/duyth/ai_coding/GAP/data/nturgb+d_rgb/S001C001P001R001A001_rgb.avi: 384x640 1 person, 511.8ms
# video 1/1 (frame 3/103) /home/duyth/ai_coding/GAP/data/nturgb+d_rgb/S001C001P001R001A001_rgb.avi: 384x640 1 person, 646.6ms
# ...
