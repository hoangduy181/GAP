# %%
import json

# %%
sample_ucla = json.load(open('../data/NW-UCLA/all_sqe/a01_s01_e00_v01.json'))

# %%
import torch
sample_ske_ucla = torch.tensor(sample_ucla['skeletons'])
sample_ske_ucla.shape
# Out:
# torch.Size([44, 20, 3])

# %%
import cv2

video_path = "/home/duyth/ai_coding/GAP/data/multiview_action_videos/a01/v02_s10_e00.avi"
cap = cv2.VideoCapture(video_path)

if cap.isOpened():
    # Get basic properties
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    # Additional properties you might want
    fourcc = int(cap.get(cv2.CAP_PROP_FOURCC))
    duration = frame_count / fps if fps > 0 else 0
    
    print(f"FPS: {fps}")
    print(f"Frame count: {frame_count}")
    print(f"Width x Height: {width} x {height}")
    print(f"Duration: {duration:.2f} seconds")
    print(f"FourCC codec: {fourcc}")
    
    cap.release()
else:
    print("Error: Could not open video file")
# Out:
# FPS: 12.0
# Frame count: 14
# Width x Height: 640 x 480
# Duration: 1.17 seconds
# FourCC codec: 877677894

# %%
import cv2

video_path = "/home/duyth/ai_coding/GAP/data/nturgb+d_rgb/S001C001P001R001A001_rgb.avi"
cap = cv2.VideoCapture(video_path)

if cap.isOpened():
    # Get basic properties
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    # Additional properties you might want
    fourcc = int(cap.get(cv2.CAP_PROP_FOURCC))
    duration = frame_count / fps if fps > 0 else 0
    
    print(f"FPS: {fps}")
    print(f"Frame count: {frame_count}")
    print(f"Width x Height: {width} x {height}")
    print(f"Duration: {duration:.2f} seconds")
    print(f"FourCC codec: {fourcc}")
    
    cap.release()
else:
    print("Error: Could not open video file")
# Out:
# FPS: 30.0
# Frame count: 103
# Width x Height: 1920 x 1080
# Duration: 3.43 seconds
# FourCC codec: 877677894
